# %%
from __future__ import print_function

# %%
# Out:
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
! pip install librosa --user
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/9e/fd/9a995b7fc18c6c17ce570b3cfdabffbd2718e4f1830e94777c4fd66e1179/scipy-1.3.0-cp36-cp36m-win_amd64.whl
# ...
#   Running setup.py bdist_wheel for librosa: started
#   Running setup.py bdist_wheel for librosa: finished with status 'done'
#   Stored in directory: C:\Users\pc-23\AppData\Local\pip\Cache\wheels\ce\49\68\87ba660f30e3977f0778e39ee2e944629cd37c2a0ce41f9ff1
#   Running setup.py bdist_wheel for audioread: started
#   Running setup.py bdist_wheel for audioread: finished with status 'done'
#   Stored in directory: C:\Users\pc-23\AppData\Local\pip\Cache\wheels\b9\64\09\0b6417df9d8ba8bc61a7d2553c5cebd714ec169644c88fc012
#   Running setup.py bdist_wheel for resampy: started
#   Running setup.py bdist_wheel for resampy: finished with status 'done'
#   Stored in directory: C:\Users\pc-23\AppData\Local\pip\Cache\wheels\ff\4f\ed\2e6c676c23efe5394bb40ade50662e90eb46e29b48324c5f9b
# Successfully built librosa audioread resampy
# ...

# %%
# !conda install -c conda-forge librosa

# %%
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
audio_path='cheerup.wav'
y,sr=librosa.load(audio_path)
ori_sent='춰럽베이베춰럽에이베'

# %%
IPython.display.Audio(data=y, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
D= librosa.amplitude_to_db(librosa.stft(y[:1024]),ref=np.max)
plt.plot(D.flatten())
plt.show()
# Out:
# C:\Users\pc-23\AppData\Roaming\Python\Python36\site-packages\librosa\core\spectrum.py:983: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '

# %%
librosa.beat
# Out:
# <module 'librosa.beat' from 'C:\\Users\\pc-23\\AppData\\Roaming\\Python\\Python36\\site-packages\\librosa\\beat.py'>

# %%
tempo, beat_frams= librosa.beat.beat_track(y=y, sr=sr)

# %%
beat_time= librosa.frames_to_time(beat_frams,sr=sr)

# %%
librosa.output.times_csv('cheer11.mp3',beat_time)

# %%
librosa.display
# Out:
# <module 'librosa.display' from 'C:\\Users\\pc-23\\AppData\\Roaming\\Python\\Python36\\site-packages\\librosa\\display.py'>

# %%
beat_time
# Out:
# array([  0.18575964,   0.53405896,   0.88235828,   1.2306576 ,
#          1.57895692,   1.92725624,   2.27555556,   2.62385488,
#          2.9721542 ,   3.32045351,   3.64553288,   3.9938322 ,
#          4.34213152,   4.69043084,   5.03873016,   5.38702948,
#          5.7353288 ,   6.08362812,   6.43192744,   6.78022676,
#          7.12852608,   7.4768254 ,   7.82512472,   8.17342404,
#          8.52172336,   8.84680272,   9.19510204,   9.56662132,
#          9.91492063,  10.24      ,  10.58829932,  10.93659864,
#         11.28489796,  11.63319728,  11.9814966 ,  12.32979592,
#         12.67809524,  13.02639456,  13.37469388,  13.7229932 ,
#         14.07129252,  14.39637188,  14.7446712 ,  15.09297052,
#         15.44126984,  15.78956916,  16.13786848,  16.4861678 ,
#         16.83446712,  17.18276644,  17.53106576,  17.87936508,
#         18.2276644 ,  18.57596372,  18.92426304,  19.27256236,
#         19.62086168,  19.969161  ,  20.31746032,  20.66575964,
# ...

# %%
# !pip install music21
# Out:
# ...
#   Running setup.py bdist_wheel for music21: started
#   Running setup.py bdist_wheel for music21: finished with status 'done'
#   Stored in directory: C:\Users\pc-23\AppData\Local\pip\Cache\wheels\7b\21\95\d396f231b8095f30aba2a1fbffbc2411fb22eb4e611ddbed57
# Successfully built music21
# ...

# %%
import music21

# %%
music21.note.Note('The_Beautifully_Short_No.15.mxl').show('vexflow')
# Out:
# ---------------------------------------------------------------------------
# PitchException                            Traceback (most recent call last)
# <ipython-input-4-675d43ac535e> in <module>()
# ----> 1 music21.note.Note('The_Beautifully_Short_No.15.mxl').show()
#
# ~\Anaconda312\lib\site-packages\music21\note.py in __init__(self, pitchName, **keywords)
#    1048                 self.pitch = pitchName
#    1049             else: # assume first argument is pitch
# -> 1050                 self.pitch = pitch.Pitch(pitchName, **keywords)
#    1051         else: # supply a default pitch
#    1052             name = 'C4'
#
# ~\Anaconda312\lib\site-packages\music21\pitch.py in __init__(self, name, **keywords)
#    1669         if name is not None:
#    1670             if not common.isNum(name):
# -> 1671                 self._setName(name) # set based on string
#    1672             else: # is a number
#    1673                 if name < 12: # is a pitchClass
#
# ...

# %%
music21.note.Note('C#4').show('braille')
# Out:
# ⠩⠐⠹

# %%
music21.note.Note('C#4').show('vexflow')

# %%
music21.note.Note('C#4').show('midi')
# Out:
#                 <div id='midiPlayerDiv7'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv7');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
s= music21.corpus.parse(workName='The_Beautifully_Short_No.15.mxsl')
# Out:
# ---------------------------------------------------------------------------
# CorpusException                           Traceback (most recent call last)
# <ipython-input-8-1252ac588638> in <module>()
# ----> 1 s= music21.corpus.parse(workName='The_Beautifully_Short_No.15.mxl')
#
# ~\Anaconda312\lib\site-packages\music21\corpus\__init__.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     323         fileExtensions=fileExtensions,
#     324         forceSource=forceSource,
# --> 325         format=format # @ReservedAssignment
#     326         )
#     327
#
# ~\Anaconda312\lib\site-packages\music21\corpus\manager.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     169     filePath = getWork(workName=workName,
#     170                         movementNumber=movementNumber,
# --> 171                         fileExtensions=fileExtensions,
#     172                        )
# ...

# %%
littleMelody = converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#")
littleMelody.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4507adab7344> in <module>()
# ----> 1 littleMelody = converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#")
#       2 littleMelody.show()
#
# NameError: name 'converter' is not defined

# %%
n = music21.note.Note("D#3")
n.duration.type = 'half'

# %%
littleMelody = music21.converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#")
littleMelody.show('vexflow')

# %%
import music21.configure.run()
# Out:
#   File "<ipython-input-17-2689133cd78d>", line 1
#     import music21.configure.run()
#                                 ^
# SyntaxError: invalid syntax

# %%
python3 -m music21.configure
# Out:
#   File "<ipython-input-18-4bc54ee8fed5>", line 1
#     python3 -m music21.configure
#                      ^
# SyntaxError: invalid syntax

# %%
music21.configure.run()
# Out:
# ______________________________________________________________________________
#
# Welcome the music21 Configuration Assistant. You will be guided through a
# number of questions to install and setup music21. Simply pressing return at a
# prompt will select a default, if available.
#
# You may run this configuration again at a later time by running
# music21/configure.py.
#
# ______________________________________________________________________________
#
# The BSD/LGPL licensed music21 software is distributed with a corpus of encoded
# compositions which are distributed with the permission of the encoders (and,
# where needed, the composers or arrangers) and where permitted under United
# States copyright law. Some encodings included in the corpus may not be used
# for commercial uses or have other restrictions: please see the licenses
# embedded in individual compositions or directories for more details.
#
# In addition to the corpus distributed with music21, other pieces are not
# ...

# %%
music21.configure
# Out:
# <module 'music21.configure' from 'C:\\Users\\pc-23\\Anaconda312\\lib\\site-packages\\music21\\configure.py'>

# %%
from music21 import *

# %%
n = note.Note("D#3")
n.duration.type = 'half'
n.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-8606e2f0c868> in <module>()
#       1 n = note.Note("D#3")
#       2 n.duration.type = 'half'
# ----> 3 n.show()
#
# ~\Anaconda312\lib\site-packages\music21\base.py in show(self, fmt, app, **keywords)
#    2578                                  app=app,
#    2579                                  subformats=subformats,
# -> 2580                                  **keywords)
#    2581
#    2582     #--------------------------------------------------------------------------
#
# ~\Anaconda312\lib\site-packages\music21\converter\subConverters.py in show(self, obj, fmt, app, subformats, **keywords)
#     358             for s in scores:
#     359                 fp = helperSubConverter.write(s, helperFormat,
# --> 360                                               subformats=helperSubformats, **keywords)
#     361
# ...

# %%
s = corpus.parse('bach/bwv65.2.xml')

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %%
s.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-0fdaf3a7a609> in <module>()
# ----> 1 s.show()
#
# ~\Anaconda312\lib\site-packages\music21\stream\__init__.py in show(self, *args, **kwargs)
#     256         if self.isSorted is False and self.autoSort:
#     257             self.sort()
# --> 258         return super().show(*args, **kwargs)
#     259
#     260     #---------------------------------------------------------------------------
#
# ~\Anaconda312\lib\site-packages\music21\base.py in show(self, fmt, app, **keywords)
#    2578                                  app=app,
#    2579                                  subformats=subformats,
# -> 2580                                  **keywords)
#    2581
#    2582     #--------------------------------------------------------------------------
#
# ...

# %%
from music21 import *
b = corpus.parse('bach/bwv66.6')
b.show() # I've altered this so it's much shorter than it should be...
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-32-9a6d0b6ded8f> in <module>()
#       1 from music21 import *
#       2 b = corpus.parse('bach/bwv66.6')
# ----> 3 b.show() # I've altered this so it's much shorter than it should be...
#
# ~\Anaconda312\lib\site-packages\music21\stream\__init__.py in show(self, *args, **kwargs)
#     256         if self.isSorted is False and self.autoSort:
#     257             self.sort()
# --> 258         return super().show(*args, **kwargs)
#     259
#     260     #---------------------------------------------------------------------------
#
# ~\Anaconda312\lib\site-packages\music21\base.py in show(self, fmt, app, **keywords)
#    2578                                  app=app,
#    2579                                  subformats=subformats,
# -> 2580                                  **keywords)
#    2581
# ...

# %%
configure.run()
# Out:
# ______________________________________________________________________________
#
# Welcome the music21 Configuration Assistant. You will be guided through a
# number of questions to install and setup music21. Simply pressing return at a
# prompt will select a default, if available.
#
# You may run this configuration again at a later time by running
# music21/configure.py.
#
# ______________________________________________________________________________
#
# The BSD/LGPL licensed music21 software is distributed with a corpus of encoded
# compositions which are distributed with the permission of the encoders (and,
# where needed, the composers or arrangers) and where permitted under United
# States copyright law. Some encodings included in the corpus may not be used
# for commercial uses or have other restrictions: please see the licenses
# embedded in individual compositions or directories for more details.
#
# In addition to the corpus distributed with music21, other pieces are not
# ...

# %%
from music21 import *

# %%
b = corpus.parse('beam')
b.show('vexflow') # I've altered this so it's much shorter than it should be...
# Out:
# ---------------------------------------------------------------------------
# CorpusException                           Traceback (most recent call last)
# <ipython-input-38-0f314d5c8f45> in <module>()
# ----> 1 b = corpus.parse('beam')
#       2 b.show('vexflow') # I've altered this so it's much shorter than it should be...
#
# ~\Anaconda312\lib\site-packages\music21\corpus\__init__.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     323         fileExtensions=fileExtensions,
#     324         forceSource=forceSource,
# --> 325         format=format # @ReservedAssignment
#     326         )
#     327
#
# ~\Anaconda312\lib\site-packages\music21\corpus\manager.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     169     filePath = getWork(workName=workName,
#     170                         movementNumber=movementNumber,
# --> 171                         fileExtensions=fileExtensions,
# ...
