# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
import numpy
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
df=pd.read_csv('pima.csv',names=['pregnant','plasma','pressure','thickness','insulin','BMI','prdigree','age','class'])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# pregnant     768 non-null int64
# plasma       768 non-null int64
# pressure     768 non-null int64
# thickness    768 non-null int64
# insulin      768 non-null int64
# BMI          768 non-null float64
# prdigree     768 non-null float64
# age          768 non-null int64
# class        768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          prdigree         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
#임신횟수당 당뇨병 발병 확률 
df[['pregnant','class']].groupby(['pregnant'],as_index=False).mean().sort_values(by='pregnant',ascending=True)
# Out:
#     pregnant     class
# 0          0  0.342342
# 1          1  0.214815
# 2          2  0.184466
# 3          3  0.360000
# 4          4  0.338235
# 5          5  0.368421
# 6          6  0.320000
# 7          7  0.555556
# 8          8  0.578947
# 9          9  0.642857
# 10        10  0.416667
# 11        11  0.636364
# 12        12  0.444444
# 13        13  0.500000
# 14        14  1.000000
# 15        15  1.000000
# 16        17  1.000000

# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.figure(figsize=(12,12))

# %%
sns.heatmap(df.corr(), linewidths=0.1,vmax=0.5,cmap=plt.cm.gist_heat,linecolor='white',annot=True)

# %%
plt.show()

# %%
grid=sns.FacetGrid(df, col='class')
grid.map(plt.hist,'plasma',bins=10)
plt.show()

# %%
dataset = numpy.loadtxt('pima.csv', delimiter=",")

# %%
# seed 값 생성
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

# %%
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 모델 컴파일
model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %%
# 모델 실행
model.fit(X, Y, epochs=200, batch_size=10)
# Out:
# W0715 11:01:27.158266  4504 deprecation_wrapper.py:119] From C:\Users\pc-23\Anaconda32\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/200
# 768/768 [==============================] - 0s 482us/step - loss: 2.4388 - acc: 0.5169
# Epoch 2/200
# 768/768 [==============================] - 0s 63us/step - loss: 0.9143 - acc: 0.6393
# Epoch 3/200
# 768/768 [==============================] - 0s 64us/step - loss: 0.7940 - acc: 0.6393
# Epoch 4/200
# 768/768 [==============================] - 0s 63us/step - loss: 0.7409 - acc: 0.6068
# Epoch 5/200
# 768/768 [==============================] - 0s 65us/step - loss: 0.6791 - acc: 0.6432
# Epoch 6/200
# 768/768 [==============================] - 0s 96us/step - loss: 0.6498 - acc: 0.6263
# Epoch 7/200
# 768/768 [==============================] - 0s 94us/step - loss: 0.6375 - acc: 0.6510
# Epoch 8/200
# ...

# %%
# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# 768/768 [==============================] - 0s 59us/step
#
#  Accuracy: 0.7734
